# %%
#| label: fig4cell
from Dash_client import TwoPercentersClient
client = TwoPercentersClient()

# %%
client.interactive_author_metrics()
# Out:
# ...
# Output()
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
client.interactive_author_comparison()
# Out:
# ...
# Output()
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
fig = client.plot_author_career("Ioannidis, John P.A.", exclude_self_citations=True)
fig.show()
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
client.interactive_author_metrics_complete()
# Out:
# ...
# Output()
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
