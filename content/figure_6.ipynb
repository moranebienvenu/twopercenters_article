# %%
#| label: fig5cell
from Dash_client import TwoPercentersClient
import plotly.io as pio
pio.renderers.default = "plotly_mimetype"

client = TwoPercentersClient()
client.interactive_group_vs_group_comparison()
# Out:
# VBox(children=(HBox(children=(Dropdown(description='Group1:', index=1, layout=Layout(width='200px'), options=(…
# Output()
# sux not found in ISO3
# ant not found in ISO3
# scg not found in ISO3
