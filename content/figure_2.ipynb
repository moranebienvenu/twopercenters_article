# %%
#| label: fig2cell
#Visualisation maps

from Dash_client import TwoPercentersClient
import plotly.io as pio
pio.renderers.default = "plotly_mimetype"


client = TwoPercentersClient("https://twopercenters.db.neurolibre.org/api/v1")
# 1. Carte mondiale simple
fig = client.plot_world_map("2021", "h", "career", "median")
fig.show()

# print("=== TEST STRUCTURE DES DONNÉES ===")
# aggregate_data = client.get_aggregate_data("country", year=None)  # career data
# if aggregate_data:
#     print(f"Nombre de pays trouvés: {len(aggregate_data)}")
#     print("Structure du premier élément:")
#     for i, country in enumerate(aggregate_data[:3]):  # Premier pays seulement
#         print(f"\nPays {i+1}:")
#         for key, value in country.items():
#             if key != 'data' or True:  # Afficher aussi les données
#                 print(f"  {key}: {type(value)} - {value}")
# else:
#     print("Aucune donnée agrégée trouvée")

# # Test avec la France
# print("\n=== RECHERCHE SPÉCIFIQUE FRANCE ===")
# france_data = None
# for country in aggregate_data:
#     if country.get('cntry', '').lower() == 'fr':
#         france_data = country
#         break

# if france_data:
#     print("Données France trouvées:")
#     for key, value in france_data.items():
#         print(f"  {key}: {value}")
# else:
#     print("France non trouvée dans les données")

# print("=== DIAGNOSTIC COMPLET ===")

# # 1. Vérifier la connexion API
# print("1. Test de connexion API...")
# aggregate_data = client.get_aggregate_data("country", year=None)
# print(f"   ✅ Données agrégées récupérées: {len(aggregate_data) if aggregate_data else 0} pays")

# # 2. Vérifier la structure des données France
# print("\n2. Structure des données France...")
# for country in aggregate_data[:5]:  # Voir les 5 premiers pays
#     code = country.get('cntry', 'N/A')
#     print(f"   Pays: {code}, Clés: {list(country.keys())}")
    
#     # Afficher les clés contenant 'career'
#     career_keys = [k for k in country.keys() if 'career' in k]
#     if career_keys:
#         print(f"     Clés career: {career_keys}")

# # 3. Test détaillé France
# print("\n3. Test détaillé France...")
# country_details = client.get_country_details("fr", "2021", "career")
# print("Résultat:", country_details)
# Out:
# ❌ No aggregate data found
# ❌ No data available for world map

# %%
# 2. Carte interactive avec animation entre les métriques
fig_interactive = client.plot_interactive_world_map()
fig_interactive.show()
# Out:
# ❌ No aggregate data found
# ❌ No aggregate data found
# ❌ No aggregate data found
# ❌ No aggregate data found
# ❌ No aggregate data found
# ❌ No aggregate data found
# ❌ No aggregate data found
# ❌ No data available for interactive map

# %%
# 3. Interface complète
interface = client.create_world_map_interface()
display(interface)

# %%
# 4. Détails d'un pays
country_details = client.get_country_details("fr", "2021", "career")
print(country_details)
