# %%
#| label: fig1cell
#Visualisation carrière par autheur

#from Dash_client import TwoPercentersClient
from Dash_client import TwoPercentersClient
client = TwoPercentersClient("https://twopercenters.db.neurolibre.org/api/v1")
client.create_world_map_interface()
# import plotly.io as pio
# pio.renderers.default = "plotly_mimetype"


# client = TwoPercentersClient("https://twopercenters.db.neurolibre.org/api/v1")
# client.show_interface()
# fig = client.plot_author_career("Ioannidis, John P.A.")
# Out:
# VBox(children=(HTML(value='<h2>🌍 Twopercenters World Map</h2>'), HBox(children=(Dropdown(description='Year:', …

# %%
# Cellule 4: Visualisation avec exclusion des auto-citations
fig = client.plot_author_career("Ioannidis, John P.A.", 
                                exclude_self_citations=True,
                                height=2500)
fig.show()

# %%
client = InteractiveTwoPercentersClient("https://twopercenters.db.neurolibre.org/api/v1")
client.create_interactive_author_plot("Ioannidis, John P.A.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 client = InteractiveTwoPercentersClient("https://twopercenters.db.neurolibre.org/api/v1")
#       2 client.create_interactive_author_plot("Ioannidis, John P.A.")
#
# NameError: name 'InteractiveTwoPercentersClient' is not defined

# %%
fig = client.plot_author_comparison(
        "Ioannidis, John P.A.", 
        "Einstein, Albert",  # Exemple
        year="2021"
    )
fig.show()
