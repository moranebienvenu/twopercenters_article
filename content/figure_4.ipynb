# %%
#| label: fig4cell
from Dash_client import TwoPercentersClient
import plotly.io as pio
pio.renderers.default = "plotly_mimetype"


client = TwoPercentersClient()

#client.interactive_author_comparison()
client.interactive_author_comparison()
# Out:
# VBox(children=(HBox(children=(VBox(children=(HBox(children=(Combobox(value='Ioannidis, John P.A.', description…
# Output()
